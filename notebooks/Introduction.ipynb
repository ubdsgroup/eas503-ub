# %% [markdown]
# # Programming and Database Fundamentals for Data Scientists - EAS503

# %% [markdown]
# ## Installing iPython (jupyter) notebook:
#
# Start by installing `Python 3`. Easiest way is to install `Anaconda Python`, which is a free and open source distribution of Python, consisting of many useful libraries.
#
# Follow the instructions at: [https://docs.continuum.io/anaconda/install/](https://docs.continuum.io/anaconda/install/)
#
# You can start IPython notebook by running
#
# ```shell
# jupyter notebook
# ```

# %% [markdown]
# ## Setting up mysql database
# In this course we will use mysql database. You can install it on your system, following instructions here:
# [https://dev.mysql.com/downloads/mysql/](https://dev.mysql.com/downloads/mysql/)
#
# After this step, you should have a mysql database running on your laptop.
# ### Installing python bindings for mysql
# To be able to connect to the mysql database, you need to install the interface (MySQLdb) that will let you connect to the database from within a python application. More information here:
#
# [http://mysql-python.sourceforge.net/](http://mysql-python.sourceforge.net/)
#
# In Unix-like environments (including MacOS), you can try:
# ```shell
# pip install mysql-python
# ```
#
# ### Alternative - PyMySQL
# #### Installation
# ```script
# pip install PyMySQL
# ```
# or
# ```script
# conda install PyMySQL
# ```
# Might need `sudo` privileges depending on your Python installation.

# %% [markdown]
# ## Demonstrating a simple data science pipeline.
# Data available from [Chicago Crime Data](https://data.cityofchicago.org/Public-Safety/Crimes-2001-to-present/ijzp-q8t2)
#
# Before starting to play with the Chicago data, you will need to import the data into your database. We will assume that the database server is running on localhost on the standard port (see mysql help for handling other settings), the username is `username` and the password is `password` (You should use better usernames and passwords!)
#
# ### Step 1: Getting the data
# Download the data from [here](https://www.cse.buffalo.edu/ubds/docs/chicago_crime_data.csv). This is only data for 2015 onwards. You can also download the full dataset here as well [here](https://www.cse.buffalo.edu/ubds/docs/chicago_crime_data_all.csv).
#
# ### Step 2: Setting up the database
# Create a new database and the empty table using the lines below. You can either go into `mysql` command prompt and copy them, or just copy them into a text file (`script.sql`) and use the command line prompt:
#
# ```shell
# mysql -u username -p < script.sql
# ```
#
# You will be prompted for your password.
# ```sql
# -- create database
# create database if not exists eas503db;
# use eas503db;
# -- create table
# drop table if exists `chicago_crime_data`;
# create table `chicago_crime_data` (
#   ID mediumint(9),
#   Case_Number text,
#   Date varchar(32),
#   Block text,
#   IUCR text,
#   Primary_Type text,
#   Description text,
#   Location_Description text,
#   Arrest varchar(6),
#   Domestic varchar(6),
#   Beat text,
#   District text,
#   Ward int,
#   Community_Area text,
#   FBI_Code text,
#   X_Coordinate float,
#   Y_Coordinate float,
#   Year int(4),
#   Updated_On varchar(32),
#   Latitude float,
#   Longitude float,
#   Location varchar(64)
# );
# ```
#
# ### Step 3: Importing data into the database.
# We will use `mysqlimport` to do the bulk import. You may use the direct INFILE LOAD command from the `mysql` prompt, which does the same thing.
#
# ```shell
# mysqlimport --local --fields-terminated-by=, --fields-enclosed-by='"' --ignore-lines=1 -u root -proot eas503db chicago_crime_data.csv
# ```
#
# ### Step 4: Converting the date elements to the correct data type
# You need final few adjustments to make sure that the date fields are stored as the correct `datetime` type. From `mysql` prompt, do the following:
# ```sql
# update chicago_crime_data set Date =  STR_TO_DATE(Date, '%m/%d/%Y %h:%i:%s %p');
# alter table chicago_crime_data modify Date datetime;
# update chicago_crime_data set Updated_On =  STR_TO_DATE(Updated_On, '%m/%d/%Y %h:%i:%s %p');
# alter table chicago_crime_data modify Updated_On datetime;
# ```

# %%
#import MySQLdb
import pymysql.cursors

# %%
# Start the connection to database
# make sure to close it after your are done
db = pymysql.connect(host="127.0.0.1",    # your host, usually localhost
                     user="root",         # your username
                     passwd="root",       # your password
                     db="eas503db")    # name of the data base

# %% [markdown]
# ### Let us start with a very simple query
# Get the total number of rows in the database

# %%
querystr = 'SELECT count(*) FROM chicago_crime_data'
cur = db.cursor()
cur.execute(querystr)
# Out:
# 1

# %%
for row in cur.fetchall():
    print("Total number of cases are:")
    print(row)
# Out:
# Total number of cases are:
# (436264,)

# %% [markdown]
# ### Doing more interesting things with SQL
# Which are the more crime ridden areas in Chicago since 2016?

# %%
querystr = 'SELECT count(*) as cnt, District FROM chicago_crime_data WHERE Date > str_to_date(\'2016/01/01\',\'%Y/%m/%d\') GROUP BY District ORDER BY cnt'
cur = db.cursor()
cur.execute(querystr)
# Out:
# 23

# %%
for row in cur.fetchall():
    print(row)
# Out:
# (5, '031')
# (7108, '020')
# (12348, '024')
# (12543, '017')
# (13844, '022')
# (14824, '016')
# (16794, '014')
# (17878, '015')
# (18487, '002')
# (19171, '005')
# (19674, '019')
# (19991, '009')
# (20191, '003')
# (20339, '010')
# (22185, '018')
# (22445, '012')
# (23000, '007')
# (23172, '001')
# (23492, '025')
# (24143, '004')
# (26629, '006')
# (27913, '008')
# (30011, '011')

# %% [markdown]
# ### Zooming into Jefferson Park (011)

# %%
querystr = 'SELECT count(*) as cnt, Primary_Type FROM chicago_crime_data WHERE District = "011" AND Date > str_to_date(\'2016/01/01\',\'%Y/%m/%d\') GROUP BY Primary_Type ORDER BY cnt'
cur = db.cursor()
cur.execute(querystr)
# Out:
# 32

# %%
for row in cur.fetchall():
    print(row)
# Out:
# (1, 'NON-CRIMINAL')
# (1, 'NON-CRIMINAL (SUBJECT SPECIFIED)')
# (1, 'NON - CRIMINAL')
# (2, 'HUMAN TRAFFICKING')
# (2, 'PUBLIC INDECENCY')
# (3, 'CONCEALED CARRY LICENSE VIOLATION')
# (4, 'OBSCENITY')
# (11, 'INTIMIDATION')
# (12, 'STALKING')
# (18, 'LIQUOR LAW VIOLATION')
# (21, 'KIDNAPPING')
# (49, 'ARSON')
# (73, 'SEX OFFENSE')
# (86, 'GAMBLING')
# (144, 'HOMICIDE')
# (158, 'CRIM SEXUAL ASSAULT')
# (203, 'OFFENSE INVOLVING CHILDREN')
# (231, 'INTERFERENCE WITH PUBLIC OFFICER')
# (274, 'PUBLIC PEACE VIOLATION')
# (644, 'CRIMINAL TRESPASS')
# (720, 'WEAPONS VIOLATION')
# (745, 'PROSTITUTION')
# (787, 'BURGLARY')
# (847, 'DECEPTIVE PRACTICE')
# (1212, 'MOTOR VEHICLE THEFT')
# (1571, 'ROBBERY')
# (1768, 'OTHER OFFENSE')
# (2200, 'ASSAULT')
# (2825, 'CRIMINAL DAMAGE')
# (3327, 'THEFT')
# (5707, 'NARCOTICS')
# (6364, 'BATTERY')

# %%
db.close()

# %% [markdown]
# ### PYTHON Library PANDAS
# One can directly read data from the csv file into a Pandas object

# %%
import pandas as pd

# %%
df = pd.read_csv('chicago_crime_data.csv',header=0)

# %%
pd.read

# %%
df
# Out:
#               ID Case Number                    Date  \
# 0       10496347    HZ237390  04/23/2016 04:55:00 PM
# 1       10496348    HZ237355  04/23/2016 02:00:00 PM
# 2       10496349    HZ237341  04/23/2016 04:10:00 PM
# 3       10496350    HZ237330  04/23/2016 01:30:00 PM
# 4       10496351    HZ237402  04/23/2016 04:45:00 PM
# 5       10496352    HZ237376  04/23/2016 04:39:00 PM
# 6       10496353    HZ237358  04/23/2016 07:00:00 AM
# 7       10496354    HZ237396  04/23/2016 12:00:00 PM
# 8       10496355    HZ237254  04/23/2016 01:00:00 AM
# 9       10496356    HZ237248  04/23/2016 03:10:00 PM
# 10      10496360    HZ237394  04/23/2016 04:58:00 PM
# 11      10496361    HZ237371  04/23/2016 09:00:00 AM
# 12      10496362    HZ237399  04/23/2016 05:00:00 PM
# 13      10496365    HZ237135  04/23/2016 01:15:00 PM
# 14      10496368    HZ237362  04/23/2016 01:30:00 PM
# 15      10496369    HZ237241  04/23/2016 02:50:00 PM
# 16      10496370    HZ237354  04/23/2016 04:30:00 PM
# 17      10496372    HZ237331  04/23/2016 03:59:00 PM
# 18      10496378    HZ237366  04/23/2016 04:30:00 PM
# 19      10496379    HZ237455  04/23/2016 06:03:00 PM
# 20      10496380    HZ237448  04/23/2016 05:30:00 PM
# 21      10496382    HZ237374  04/23/2016 12:37:00 PM
# 22      10496387    HZ237352  04/23/2016 01:00:00 AM
# 23      10496388    HZ237474  04/23/2016 09:20:00 AM
# 24      10496390    HZ237477  04/23/2016 03:00:00 PM
# 25      10496391    HZ237391  04/23/2016 04:52:00 PM
# 26      10496392    HZ237345  04/23/2016 06:00:00 AM
# 27      10496393    HZ237485  04/23/2016 06:15:00 PM
# 28      10496394    HZ237299  04/23/2016 07:45:00 AM
# 29      10496396    HZ237332  04/23/2016 02:15:00 PM
# ...          ...         ...                     ...
# 436234  10496273    HZ237193  04/23/2016 01:00:00 PM
# 436235  10496276    HZ237170  04/23/2016 02:00:00 AM
# 436236  10496277    HZ237253  04/23/2016 12:00:00 PM
# 436237  10496278    HZ237301  04/23/2016 06:00:00 AM
# 436238  10496281    HZ237220  04/23/2016 01:55:00 PM
# 436239  10496283    HZ237168  04/23/2016 01:10:00 PM
# 436240  10496287    HZ237282  04/23/2016 03:20:00 PM
# 436241  10496289    HZ237223  04/23/2016 02:30:00 PM
# 436242  10496293    HZ237130  04/23/2016 10:00:00 AM
# 436243  10496299    HZ237194  04/23/2016 12:05:00 PM
# 436244  10496300    HZ237289  04/23/2016 01:30:00 AM
# 436245  10496304    HZ237214  04/23/2016 02:10:00 PM
# 436246  10496306    HZ237309  04/23/2016 03:30:00 PM
# 436247  10496308    HZ237238  04/23/2016 03:00:00 PM
# 436248  10496309    HZ237279  04/23/2016 02:45:00 PM
# 436249  10496310    HZ237259  04/23/2016 03:10:00 PM
# 436250  10496313    HZ237260  04/23/2016 03:08:00 PM
# 436251  10496315    HZ237150  04/23/2016 08:00:00 AM
# 436252  10496317    HZ237154  04/23/2016 12:30:00 PM
# 436253  10496318    HZ237137  04/23/2016 01:17:00 PM
# 436254  10496319    HZ237265  04/23/2016 02:10:00 PM
# 436255  10496321    HZ237292  04/23/2016 02:20:00 PM
# 436256  10496322    HZ237302  04/23/2016 02:38:00 PM
# 436257  10496325    HZ237337  04/23/2016 03:45:00 PM
# 436258  10496332    HZ237318  04/23/2016 03:40:00 PM
# 436259  10496334    HZ237389  04/23/2016 02:00:00 AM
# 436260  10496337    HZ237380  04/23/2016 09:00:00 AM
# 436261  10496339    HZ237230  04/23/2016 12:00:00 PM
# 436262  10496341    HZ237435  04/23/2016 03:00:00 PM
# 436263  10496344    HZ237360  04/23/2016 04:22:00 PM
#
#                                       Block  IUCR         Primary Type  \
# 0                      001XX N PARKSIDE AVE  1310      CRIMINAL DAMAGE
# 1                       0000X E RIVERWALK S  0820                THEFT
# 2                           003XX W 35TH ST  0495              BATTERY
# 3                         040XX N MAJOR AVE  031A              ROBBERY
# 4                        084XX S DREXEL AVE  2820        OTHER OFFENSE
# 5                      018XX S ST LOUIS AVE  0820                THEFT
# 6                          002XX E HURON ST  0890                THEFT
# 7                      023XX S TRUMBULL AVE  2825        OTHER OFFENSE
# 8                      070XX S JEFFERY BLVD  2825        OTHER OFFENSE
# 9                    095XX S COMMERCIAL AVE  1320      CRIMINAL DAMAGE
# 10                          108XX S TROY ST  1320      CRIMINAL DAMAGE
# 11                     079XX S KINGSTON AVE  0610             BURGLARY
# 12                    095XX S MARQUETTE AVE  0560              ASSAULT
# 13                 075XX S STONY ISLAND AVE  0860                THEFT
# 14                         016XX N WELLS ST  0890                THEFT
# 15                        054XX S HONORE ST  1320      CRIMINAL DAMAGE
# 16                        017XX W HOWARD ST  0860                THEFT
# 17                        032XX W NORTH AVE  051A              ASSAULT
# 18                     095XX S MUSKEGON AVE  1320      CRIMINAL DAMAGE
# 19                      043XX S ASHLAND AVE  0860                THEFT
# 20                         015XX W 102ND PL  0820                THEFT
# 21                      069XX N SHERIDAN RD  0890                THEFT
# 22                      060XX N LINCOLN AVE  0313              ROBBERY
# 23                        053XX S LAFLIN ST  0820                THEFT
# 24                       076XX S YATES BLVD  1310      CRIMINAL DAMAGE
# 25                     082XX S EXCHANGE AVE  0486              BATTERY
# 26                      094XX S LA SALLE ST  0910  MOTOR VEHICLE THEFT
# 27                       076XX S YATES BLVD  1310      CRIMINAL DAMAGE
# 28                       054XX W CRYSTAL ST  5002        OTHER OFFENSE
# 29      064XX S DR MARTIN LUTHER KING JR DR  0440              BATTERY
# ...                                     ...   ...                  ...
# 436234                 039XX S ARTESIAN AVE  0460              BATTERY
# 436235                     006XX N CLARK ST  1150   DECEPTIVE PRACTICE
# 436236                009XX N MASSASOIT AVE  1153   DECEPTIVE PRACTICE
# 436237                033XX W EVERGREEN AVE  1320      CRIMINAL DAMAGE
# 436238                     008XX W 104TH ST  1812            NARCOTICS
# 436239                063XX S FRANCISCO AVE  2825        OTHER OFFENSE
# 436240               056XX N CUMBERLAND AVE  0810                THEFT
# 436241                    029XX W CERMAK RD  0486              BATTERY
# 436242                   029XX S POPLAR AVE  0820                THEFT
# 436243                     010XX N CLARK ST  0890                THEFT
# 436244                 002XX W INSTITUTE PL  1150   DECEPTIVE PRACTICE
# 436245                   052XX W MADISON ST  0860                THEFT
# 436246                  009XX W BELMONT AVE  0486              BATTERY
# 436247                  001XX N WESTERN AVE  1310      CRIMINAL DAMAGE
# 436248                    049XX N MARINE DR  0560              ASSAULT
# 436249                     049XX W ADAMS ST  0460              BATTERY
# 436250                 047XX S MICHIGAN AVE  1121   DECEPTIVE PRACTICE
# 436251                      025XX W 51ST ST  0560              ASSAULT
# 436252               035XX S MARSHFIELD AVE  2825        OTHER OFFENSE
# 436253                   076XX S CICERO AVE  0860                THEFT
# 436254                      001XX W 79TH ST  0860                THEFT
# 436255                     070XX S STATE ST  1121   DECEPTIVE PRACTICE
# 436256                      042XX W 13TH ST  0430              BATTERY
# 436257                086XX S BALTIMORE AVE  1811            NARCOTICS
# 436258                     0000X S STATE ST  0860                THEFT
# 436259                    028XX N MOODY AVE  1320      CRIMINAL DAMAGE
# 436260                 065XX W CORNELIA AVE  0810                THEFT
# 436261                009XX N MASSASOIT AVE  0820                THEFT
# 436262                 003XX W JACKSON BLVD  0810                THEFT
# 436263             024XX S CENTRAL PARK AVE  4625        OTHER OFFENSE
#
#                                  Description           Location Description  \
# 0                                TO PROPERTY                      APARTMENT
# 1                             $500 AND UNDER                       SIDEWALK
# 2             AGGRAVATED OF A SENIOR CITIZEN           SPORTS ARENA/STADIUM
# 3                             ARMED: HANDGUN                          ALLEY
# 4                           TELEPHONE THREAT                      RESIDENCE
# 5                             $500 AND UNDER                      APARTMENT
# 6                              FROM BUILDING      HOSPITAL BUILDING/GROUNDS
# 7                    HARASSMENT BY TELEPHONE                      APARTMENT
# 8                    HARASSMENT BY TELEPHONE                  BAR OR TAVERN
# 9                                 TO VEHICLE                         STREET
# 10                                TO VEHICLE                         STREET
# 11                            FORCIBLE ENTRY                      APARTMENT
# 12                                    SIMPLE                      RESIDENCE
# 13                              RETAIL THEFT             GROCERY FOOD STORE
# 14                             FROM BUILDING                          OTHER
# 15                                TO VEHICLE                         STREET
# 16                              RETAIL THEFT             GROCERY FOOD STORE
# 17                       AGGRAVATED: HANDGUN             SMALL RETAIL STORE
# 18                                TO VEHICLE                         STREET
# 19                              RETAIL THEFT             SMALL RETAIL STORE
# 20                            $500 AND UNDER                  PARK PROPERTY
# 21                             FROM BUILDING        RESIDENCE PORCH/HALLWAY
# 22             ARMED: OTHER DANGEROUS WEAPON                    HOTEL/MOTEL
# 23                            $500 AND UNDER                       SIDEWALK
# 24                               TO PROPERTY                      APARTMENT
# 25                   DOMESTIC BATTERY SIMPLE                       SIDEWALK
# 26                                AUTOMOBILE                         STREET
# 27                               TO PROPERTY                      RESIDENCE
# 28                     OTHER VEHICLE OFFENSE                         STREET
# 29      AGG: HANDS/FIST/FEET NO/MINOR INJURY                      APARTMENT
# ...                                      ...                            ...
# 436234                                SIMPLE                      APARTMENT
# 436235                     CREDIT CARD FRAUD                         STREET
# 436236   FINANCIAL IDENTITY THEFT OVER $ 300                      APARTMENT
# 436237                            TO VEHICLE                         STREET
# 436238        POSS: CANNABIS MORE THAN 30GMS                         STREET
# 436239               HARASSMENT BY TELEPHONE                      RESIDENCE
# 436240                             OVER $500                    HOTEL/MOTEL
# 436241               DOMESTIC BATTERY SIMPLE                      APARTMENT
# 436242                        $500 AND UNDER                  PARK PROPERTY
# 436243                         FROM BUILDING                          OTHER
# 436244                     CREDIT CARD FRAUD                  BAR OR TAVERN
# 436245                          RETAIL THEFT              CONVENIENCE STORE
# 436246               DOMESTIC BATTERY SIMPLE                      CTA TRAIN
# 436247                           TO PROPERTY                    GAS STATION
# 436248                                SIMPLE                  PARK PROPERTY
# 436249                                SIMPLE                          ALLEY
# 436250               COUNTERFEITING DOCUMENT                    GAS STATION
# 436251                                SIMPLE                      RESIDENCE
# 436252               HARASSMENT BY TELEPHONE                      RESIDENCE
# 436253                          RETAIL THEFT             SMALL RETAIL STORE
# 436254                          RETAIL THEFT               DEPARTMENT STORE
# 436255               COUNTERFEITING DOCUMENT             SMALL RETAIL STORE
# 436256         AGGRAVATED: OTHER DANG WEAPON  RESIDENTIAL YARD (FRONT/BACK)
# 436257          POSS: CANNABIS 30GMS OR LESS                       SIDEWALK
# 436258                          RETAIL THEFT               DEPARTMENT STORE
# 436259                            TO VEHICLE                         STREET
# 436260                             OVER $500         VEHICLE NON-COMMERCIAL
# 436261                        $500 AND UNDER                         STREET
# 436262                             OVER $500                       SIDEWALK
# 436263                      PAROLE VIOLATION                          ALLEY
#
#         Arrest  Domestic              ...                Ward  Community Area  \
# 0        False     False              ...                29.0              25
# 1        False     False              ...                42.0              32
# 2         True     False              ...                11.0              34
# 3        False     False              ...                38.0              15
# 4        False      True              ...                 8.0              44
# 5        False      True              ...                24.0              29
# 6        False     False              ...                42.0               8
# 7        False      True              ...                22.0              30
# 8        False      True              ...                 5.0              43
# 9        False     False              ...                10.0              51
# 10       False     False              ...                19.0              74
# 11       False     False              ...                 7.0              46
# 12       False      True              ...                10.0              51
# 13       False     False              ...                 5.0              43
# 14       False     False              ...                43.0               7
# 15       False      True              ...                16.0              61
# 16        True     False              ...                49.0               1
# 17       False      True              ...                26.0              23
# 18       False     False              ...                10.0              51
# 19       False     False              ...                12.0              61
# 20       False     False              ...                19.0              72
# 21       False     False              ...                49.0               1
# 22       False     False              ...                50.0              13
# 23       False     False              ...                16.0              61
# 24       False     False              ...                 7.0              43
# 25       False      True              ...                 7.0              46
# 26       False     False              ...                21.0              49
# 27       False     False              ...                 7.0              43
# 28       False      True              ...                37.0              25
# 29       False     False              ...                20.0              42
# ...        ...       ...              ...                 ...             ...
# 436234   False     False              ...                12.0              58
# 436235   False     False              ...                42.0               8
# 436236   False     False              ...                29.0              25
# 436237   False     False              ...                26.0              23
# 436238    True     False              ...                34.0              73
# 436239   False     False              ...                15.0              66
# 436240   False     False              ...                41.0              10
# 436241   False      True              ...                12.0              30
# 436242   False     False              ...                11.0              60
# 436243   False     False              ...                42.0               8
# 436244   False     False              ...                27.0               8
# 436245    True     False              ...                28.0              25
# 436246   False      True              ...                44.0               6
# 436247   False     False              ...                 2.0              28
# 436248   False     False              ...                48.0               3
# 436249   False     False              ...                28.0              25
# 436250   False     False              ...                 3.0              38
# 436251   False     False              ...                14.0              63
# 436252   False     False              ...                11.0              59
# 436253    True     False              ...                13.0              65
# 436254    True     False              ...                17.0              69
# 436255   False     False              ...                 6.0              69
# 436256   False     False              ...                24.0              29
# 436257    True     False              ...                10.0              46
# 436258    True     False              ...                42.0              32
# 436259   False     False              ...                29.0              19
# 436260   False     False              ...                36.0              17
# 436261   False     False              ...                29.0              25
# 436262   False     False              ...                 2.0              32
# 436263    True     False              ...                22.0              30
#
#         FBI Code  X Coordinate Y Coordinate  Year              Updated On  \
# 0             14     1138578.0    1900413.0  2016  04/30/2016 03:51:13 PM
# 1             06     1176778.0    1902518.0  2016  04/30/2016 03:51:13 PM
# 2            04B     1174431.0    1881739.0  2016  04/30/2016 03:51:13 PM
# 3             03     1137626.0    1926291.0  2016  04/30/2016 03:51:13 PM
# 4             26     1183692.0    1849271.0  2016  04/30/2016 03:51:13 PM
# 5             06     1153327.0    1890818.0  2016  04/30/2016 03:51:13 PM
# 6             06     1178046.0    1905133.0  2016  04/30/2016 03:51:13 PM
# 7             26     1153734.0    1888259.0  2016  04/30/2016 03:51:13 PM
# 8             26     1190765.0    1858575.0  2016  04/30/2016 03:51:13 PM
# 9             14     1197803.0    1842283.0  2016  04/30/2016 03:51:13 PM
# 10            14     1157261.0    1832670.0  2016  04/30/2016 03:51:13 PM
# 11            05     1194564.0    1852850.0  2016  04/30/2016 03:51:13 PM
# 12           08A     1195917.0    1842256.0  2016  04/30/2016 03:51:13 PM
# 13            06     1188123.0    1855151.0  2016  04/30/2016 03:51:13 PM
# 14            06     1174403.0    1911179.0  2016  04/30/2016 03:51:13 PM
# 15            14     1164943.0    1868582.0  2016  04/30/2016 03:51:13 PM
# 16            06     1163126.0    1950347.0  2016  04/30/2016 03:51:13 PM
# 17           04A     1154595.0    1910455.0  2016  04/30/2016 03:51:13 PM
# 18            14     1196670.0    1842343.0  2016  04/30/2016 03:51:13 PM
# 19            06     1166399.0    1875949.0  2016  04/30/2016 03:51:13 PM
# 20            06     1167751.0    1836640.0  2016  04/30/2016 03:51:13 PM
# 21            06     1166747.0    1946376.0  2016  04/30/2016 03:51:13 PM
# 22            03     1153588.0    1940385.0  2016  04/30/2016 03:51:13 PM
# 23            06     1167240.0    1869424.0  2016  04/30/2016 03:51:13 PM
# 24            14     1193528.0    1854748.0  2016  04/30/2016 03:51:13 PM
# 25           08B     1197255.0    1851012.0  2016  04/30/2016 03:51:13 PM
# 26            07     1176944.0    1842276.0  2016  04/30/2016 03:51:13 PM
# 27            14     1193528.0    1854748.0  2016  04/30/2016 03:51:13 PM
# 28            26     1139621.0    1907789.0  2016  04/30/2016 03:51:13 PM
# 29           08B     1180028.0    1862391.0  2016  04/30/2016 03:51:13 PM
# ...          ...           ...          ...   ...                     ...
# 436234       08B     1160670.0    1878492.0  2016  04/30/2016 03:51:13 PM
# 436235        11     1175423.0    1904628.0  2016  04/30/2016 03:51:13 PM
# 436236        11     1137851.0    1905766.0  2016  04/30/2016 03:51:13 PM
# 436237        14     1153779.0    1908780.0  2016  04/30/2016 03:51:13 PM
# 436238        18     1172721.0    1835882.0  2016  04/30/2016 03:51:13 PM
# 436239        26     1158140.0    1862383.0  2016  04/30/2016 03:51:13 PM
# 436240        06     1119313.0    1936269.0  2016  04/30/2016 03:51:13 PM
# 436241       08B     1156944.0    1889242.0  2016  04/30/2016 03:51:13 PM
# 436242        06     1170627.0    1885385.0  2016  04/30/2016 03:51:13 PM
# 436243        06     1175350.0    1907323.0  2016  04/30/2016 03:51:13 PM
# 436244        11     1174454.0    1905982.0  2016  04/30/2016 03:51:13 PM
# 436245        06     1141512.0    1899523.0  2016  04/30/2016 03:51:13 PM
# 436246       08B     1169269.0    1921430.0  2016  04/30/2016 03:51:13 PM
# 436247        14     1160392.0    1900695.0  2016  04/30/2016 03:51:13 PM
# 436248       08A     1169906.0    1933191.0  2016  04/30/2016 03:51:13 PM
# 436249       08B     1143588.0    1898880.0  2016  04/30/2016 03:51:13 PM
# 436250        10     1177953.0    1873730.0  2016  04/30/2016 03:51:13 PM
# 436251       08A     1160083.0    1870765.0  2016  04/30/2016 03:51:13 PM
# 436252        26     1165928.0    1881229.0  2016  04/30/2016 03:51:13 PM
# 436253        06     1145727.0    1853720.0  2016  04/30/2016 03:51:13 PM
# 436254        06     1176766.0    1852607.0  2016  04/30/2016 03:51:13 PM
# 436255        10     1177506.0    1858207.0  2016  04/30/2016 03:51:13 PM
# 436256       04B     1148353.0    1893703.0  2016  04/30/2016 03:51:13 PM
# 436257        18     1198316.0    1848177.0  2016  04/30/2016 03:51:13 PM
# 436258        06     1176389.0    1900278.0  2016  04/30/2016 03:51:13 PM
# 436259        14     1134912.0    1918253.0  2016  04/30/2016 03:51:13 PM
# 436260        06     1131964.0    1922560.0  2016  04/30/2016 03:51:13 PM
# 436261        06     1137851.0    1905766.0  2016  04/30/2016 03:51:13 PM
# 436262        06     1174273.0    1898942.0  2016  04/30/2016 03:51:13 PM
# 436263        26     1152759.0    1887500.0  2016  04/30/2016 03:51:13 PM
#
#          Latitude  Longitude                       Location
# 0       41.882858 -87.766599   (41.88285803, -87.766599362)
# 1       41.887856 -87.626264  (41.887856357, -87.626264274)
# 2       41.830890 -87.635503  (41.830890037, -87.635503335)
# 3       41.953887 -87.769470   (41.953887423, -87.76947041)
# 4       41.741584 -87.602537  (41.741583562, -87.602537135)
# 5       41.856248 -87.712695  (41.856248253, -87.712694737)
# 6       41.895003 -87.621528   (41.895003278, -87.62152816)
# 7       41.849218 -87.711269  (41.849217975, -87.711268873)
# 8       41.766947 -87.576322   (41.766946791, -87.57632241)
# 9       41.722067 -87.551069   (41.722067458, -87.55106874)
# 10      41.696603 -87.699827   (41.696602652, -87.69982715)
# 11      41.751144 -87.562586  (41.751144367, -87.562585832)
# 12      41.722040 -87.557978  (41.722040188, -87.557977613)
# 13      41.757614 -87.586115  (41.757614433, -87.586115266)
# 14      41.911676 -87.634727  (41.911675961, -87.634726954)
# 15      41.794992 -87.670688  (41.794991951, -87.670687529)
# 16      42.019399 -87.675049  (42.019399237, -87.675049485)
# 17      41.910109 -87.707515  (41.910108908, -87.707514877)
# 18      41.722260 -87.555217   (41.72226028, -87.555216669)
# 19      41.815177 -87.665138  (41.815176924, -87.665138344)
# 20      41.707279 -87.661305    (41.70727883, -87.66130546)
# 21      42.008426 -87.661839   (42.00842557, -87.661839303)
# 22      41.992259 -87.710415  (41.992259008, -87.710415066)
# 23      41.797254 -87.662240  (41.797253602, -87.662240313)
# 24      41.756378 -87.566320  (41.756378035, -87.566320174)
# 25      41.746034 -87.552786  (41.746034186, -87.552785975)
# 26      41.722543 -87.627472   (41.72254298, -87.627471529)
# 27      41.756378 -87.566320  (41.756378035, -87.566320174)
# 28      41.903080 -87.762589    (41.903079719, -87.7625892)
# 29      41.777671 -87.615561   (41.777670858, -87.61556066)
# ...           ...        ...                            ...
# 436234  41.822276 -87.686083  (41.822275543, -87.686083015)
# 436235  41.893677 -87.631177  (41.893676841, -87.631176812)
# 436236  41.897560 -87.769140   (41.897560489, -87.76913973)
# 436237  41.905529 -87.710557  (41.905528856, -87.710557226)
# 436238  41.705091 -87.643128  (41.705090888, -87.643127545)
# 436239  41.778122 -87.695803  (41.778122217, -87.695802844)
# 436240  41.981579 -87.836580  (41.981579153, -87.836580014)
# 436241  41.851851 -87.699461   (41.851851025, -87.69946113)
# 436242  41.840979 -87.649354   (41.84097894, -87.649353839)
# 436243  41.901074 -87.631364   (41.901073698, -87.63136393)
# 436244  41.897414 -87.634695  (41.897413995, -87.634695089)
# 436245  41.880362 -87.755847  (41.880362084, -87.755847438)
# 436246  41.939918 -87.653289   (41.93991842, -87.653288878)
# 436247  41.883209 -87.686489  (41.883208624, -87.686489297)
# 436248  41.972177 -87.650603  (41.972177117, -87.650603352)
# 436249  41.878559 -87.748241  (41.878559028, -87.748240581)
# 436250  41.808833 -87.622824  (41.808833439, -87.622824022)
# 436251  41.801084 -87.688449   (41.801083808, -87.68844919)
# 436252  41.829676 -87.666716  (41.829675848, -87.666715778)
# 436253  41.754593 -87.741529  (41.754592961, -87.741528537)
# 436254  41.750897 -87.627813   (41.75089655, -87.627813307)
# 436255  41.766247 -87.624933  (41.766246905, -87.624932618)
# 436256  41.864262 -87.730878  (41.864262257, -87.730877728)
# 436257  41.738228 -87.548993  (41.738228259, -87.548993019)
# 436258  41.881718 -87.627760   (41.88171846, -87.627760426)
# 436259  41.931879 -87.779638  (41.931878855, -87.779638422)
# 436260  41.943749 -87.790372  (41.943749489, -87.790371837)
# 436261  41.897560 -87.769140   (41.897560489, -87.76913973)
# 436262  41.878100 -87.635570  (41.878099868, -87.635570127)
# 436263  41.847155 -87.714867  (41.847154512, -87.714867318)
#
# [436264 rows x 22 columns]

# %% [markdown]
# Many of the operations that can be done as SQL queries on the database, can also be done on a `Pandas` object. Then what is benefit of a database?
#
# ## Measuring performance of a Python code
# Here we will focus on two types of performance metrics:
# #### Speed - time taken to run the code on the machine
# We will use a Python tool called `timeit` to measure the time.
#
# We will first define two `functions` (snippets of code that can be called repeatedly) to use `mysql` and `Pandas`

# %%
def pd_performance():
    df = pd.read_csv('chicago_crime_data.csv',header=0)
    cnt = len(df.index)
    
def db_performance():
    db = pymysql.connect(host="127.0.0.1",    # your host, usually localhost
                     user="root",         # your username
                     passwd="root",       # your password
                     db="eas503db")    # name of the data base
    querystr = 'SELECT count(*) FROM chicago_crime_data'
    cur = db.cursor()
    cur.execute(querystr)

    for row in cur.fetchall():
        cnt = row
    db.close()

# %%
timeit pd_performance()
# Out:
# 2.09 s ± 98.6 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
timeit db_performance()
# Out:
# 137 ms ± 520 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# #### Space - memory used to run the code on the machine
# We will use another Python tool called `memory_profiler` for this. For more see - https://pypi.org/project/memory_profiler/. Conda users may install the tool using:
# ```shell
# conda install memory_profiler
# ```
#
# Unfortunately, the `memory_profiler` does not support notebooks. So we will run these two codes from the command line.

# %%
import pandas as pd
from memory_profiler import profile

def pd_performance():
    df = pd.read_csv('chicago_crime_data.csv',header=0)
    cnt = len(df.index)

# %% [markdown]
# Save the above snippet into a file called `pd_demo.py`. Then run:
# ```shell
# python -m memory_profiler pd_demo.py
# ```

# %%
import pymysql.cursors
from memory_profiler import profile

def db_performance():
    db = pymysql.connect(host="127.0.0.1",    # your host, usually localhost
                     user="root",         # your username
                     passwd="root",       # your password
                     db="eas503db")    # name of the data base
    querystr = 'SELECT count(*) FROM chicago_crime_data'
    cur = db.cursor()
    cur.execute(querystr)

    for row in cur.fetchall():
        cnt = row
    db.close()

# %% [markdown]
# Save the above snippet into a file called `db_demo.py`. Then run:
# ```shell
# python -m memory_profiler db_demo.py
# ```

# %% [markdown]
# ### Observations:
# The output of the `memory_profiler` gives us:
#
# For `pd_demo.py`:
# ```
# Line #    Mem usage    Increment   Line Contents
# ================================================
#      4     77.6 MiB     77.6 MiB   @profile
#      5                             def pd_performance():
#      6    270.0 MiB    192.4 MiB       df = pd.read_csv('chicago_crime_data.csv',header=0)
#      7    270.0 MiB      0.0 MiB       cnt = len(df.index)
# ```
#
# For `db_demo.py`:
# ```
# Line #    Mem usage    Increment   Line Contents
# ================================================
#      4     49.5 MiB     49.5 MiB   @profile
#      5                             def db_performance():
#      6     49.5 MiB      0.0 MiB       db = pymysql.connect(host="127.0.0.1",    # your host, usually localhost
#      7     49.5 MiB      0.0 MiB                        user="root",         # your username
#      8     49.5 MiB      0.0 MiB                        passwd="root",       # your password
#      9     49.7 MiB      0.2 MiB                        db="eas503db")    # name of the data base
#     10     49.7 MiB      0.0 MiB       querystr = 'SELECT count(*) FROM chicago_crime_data'
#     11     49.7 MiB      0.0 MiB       cur = db.cursor()
#     12     49.7 MiB      0.0 MiB       cur.execute(querystr)
#     13
#     14     49.7 MiB      0.0 MiB       for row in cur.fetchall():
#     15     49.7 MiB      0.0 MiB           cnt = row
#     16     49.7 MiB      0.0 MiB       db.close()
# ```
#
# Pulling data from the database is better, both in terms of memory usage and speed, than reading a file. Of course, this does not include the cost of the database itself. But, given that same database will be used over and over, and typically by many applications, that cost tends to be _amortized_.
